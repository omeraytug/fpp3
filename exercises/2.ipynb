# %% [markdown]
# # imports

# %%
import polars as pl

bricks = pl.read_csv(
    "../data/tsibbledata/aus_production.csv",
    null_values=["NA"]
)

lynx = pl.read_csv("../data/tsibbledata/pelt.csv", null_values=["NA"])
goog_close = pl.read_csv("../data/tsibbledata/gafa_stock.csv", null_values=["NA"])
demand = pl.read_csv("../data/tsibbledata/vic_elec.csv", null_values=["NA"])

# %%
demand
# Out:
# shape: (52_608, 5)
# ┌──────────────────────┬─────────────┬─────────────┬────────────┬─────────┐
# │ Time                 ┆ Demand      ┆ Temperature ┆ Date       ┆ Holiday │
# │ ---                  ┆ ---         ┆ ---         ┆ ---        ┆ ---     │
# │ str                  ┆ f64         ┆ f64         ┆ str        ┆ bool    │
# ╞══════════════════════╪═════════════╪═════════════╪════════════╪═════════╡
# │ 2011-12-31T13:00:00Z ┆ 4382.825174 ┆ 21.4        ┆ 2012-01-01 ┆ true    │
# │ 2011-12-31T13:30:00Z ┆ 4263.365526 ┆ 21.05       ┆ 2012-01-01 ┆ true    │
# │ 2011-12-31T14:00:00Z ┆ 4048.966046 ┆ 20.7        ┆ 2012-01-01 ┆ true    │
# │ 2011-12-31T14:30:00Z ┆ 3877.56333  ┆ 20.55       ┆ 2012-01-01 ┆ true    │
# │ 2011-12-31T15:00:00Z ┆ 4036.229746 ┆ 20.4        ┆ 2012-01-01 ┆ true    │
# │ …                    ┆ …           ┆ …           ┆ …          ┆ …       │
# │ 2014-12-31T10:30:00Z ┆ 3873.448714 ┆ 19.0        ┆ 2014-12-31 ┆ false   │
# ...
